# %%
from transformers import AutoTokenizer, AutoModelForSequenceClassification
import torch.nn.functional as F
tokenizer = AutoTokenizer.from_pretrained("nlptown/bert-base-multilingual-uncased-sentiment")
model = AutoModelForSequenceClassification.from_pretrained("nlptown/bert-base-multilingual-uncased-sentiment")

# %%
def compute_stars(comment):
    pt_batch = tokenizer(comment, padding=True, truncation=True, max_length=512, return_tensors="pt")
    pt_outputs = model(**pt_batch)
    tensor = F.softmax(pt_outputs.logits, dim=-1)
    
    def compute_avg_stars(vals):
        return (1 * vals[0]) + (2 * vals[1]) + (3 * vals[2]) + (4 * vals[3]) + (5 * vals[4])

    return list(map(compute_avg_stars, tensor.tolist()))
    
    #return { "1": vals[0], "2": vals[1], "3": vals[2], "4": vals[3], "5": vals[4], "avg": avg_stars }

# %%
import pandas as pd
import numpy as np

reviews_path = '../data/amazon-reviews.json'
products_path = '../data/amazon-products.json'
stars_path = '../data/computed_stars.json'

reviews_df = pd.read_json(reviews_path)
products_df = pd.read_json(products_path)
stars_df = pd.read_json(stars_path, typ="series")

# %%
products_df
# Out:
#                            _id  \
# 0     60a64efdc6b6ff187482412d
# 1     60a64f40c6b6ff187482425a
# 2     60a64f42c6b6ff1874824387
# 3     60a64f81c6b6ff18748243a8
# 4     60a65012c6b6ff18748244d5
# ...                        ...
# 1855  60a6b53f6dccd831e8d98bdb
# 1856  60a6b5726dccd831e8d98d08
# 1857  60a6b5776dccd831e8d98e1b
# 1858  60a6b57c6dccd831e8d98f43
# 1859  60a6b57e6dccd831e8d99070
#
#                                              categories  \
# 0     [Beauty & Personal Care, Makeup, Makeup Remove...
# 1     [Beauty & Personal Care, Skin Care, Face, Crea...
# 2     [Beauty & Personal Care, Skin Care, Face, Clea...
# 3     [Beauty & Personal Care, Skin Care, Face, Clea...
# 4     [Beauty & Personal Care, Skin Care, Body, Clea...
# ...                                                 ...
# 1855  [Home & Kitchen, Kitchen & Dining, Dining & En...
# 1856  [Office Products, Office & School Supplies, Bi...
# 1857  [Patio, Lawn & Garden, Gardening & Lawn Care, ...
# 1858  [Arts, Crafts & Sewing, Painting, Drawing & Ar...
# 1859  [Automotive, Exterior Accessories, Towing Prod...
#
#                                    storeId            storeName price  \
# 0     3BC8CF14-3F35-41A4-9BF3-705A7FB2B6B6           Neutrogena  None
# 1     0CA2A9B7-7695-43AF-98D9-FB55761E0796               CeraVe  None
# 2     0CA2A9B7-7695-43AF-98D9-FB55761E0796               CeraVe  None
# 3     3BC8CF14-3F35-41A4-9BF3-705A7FB2B6B6           Neutrogena  None
# 4     9B9CC7AD-3D51-4456-9A0C-0614D1D92F13                 Dove  None
# ...                                    ...                  ...   ...
# 1855  8780CBF9-8B22-4381-8D37-0AAC20F190F2  American Metalcraft  None
# 1856  947C6949-CF8E-4BD3-914A-B411DD3E4433        Amazon Basics  None
# 1857  1D2A0DDE-57D0-4030-8B1F-5C33E3A4A94F              Fiskars  None
# 1858  4E822E20-FC23-45E9-BCD6-3275BBFBAF5E          Colorations  None
# 1859  AE9F00D1-C11E-4A9B-AFEB-B4EA056EF019              Fastway  None
#
#                                                    href  \
# 0     https://www.amazon.com/Neutrogena-Oil-Free-Eye...
# 1     https://www.amazon.com/CeraVe-Facial-Moisturiz...
# 2     https://www.amazon.com/CeraVe-Hydrating-Facial...
# 3     https://www.amazon.com/Neutrogena-Cleansing-Hy...
# 4     https://www.amazon.com/Dove-Body-Wash-Pump-Moi...
# ...                                                 ...
# 1855  https://www.amazon.com/American-Metalcraft-MEL...
# 1856  https://www.amazon.com/AmazonBasics-D-Ring-Bin...
# 1857  https://www.amazon.com/Fiskars-29-Inch-Machete...
# 1858  https://www.amazon.com/Colorations-SWTALL-Simp...
# 1859  https://www.amazon.com/Fastway-80-01-2204-Zip-...
#
#                       origin protocol            host  \
# 0     https://www.amazon.com   https:  www.amazon.com
# 1     https://www.amazon.com   https:  www.amazon.com
# 2     https://www.amazon.com   https:  www.amazon.com
# 3     https://www.amazon.com   https:  www.amazon.com
# 4     https://www.amazon.com   https:  www.amazon.com
# ...                      ...      ...             ...
# 1855  https://www.amazon.com   https:  www.amazon.com
# 1856  https://www.amazon.com   https:  www.amazon.com
# 1857  https://www.amazon.com   https:  www.amazon.com
# 1858  https://www.amazon.com   https:  www.amazon.com
# 1859  https://www.amazon.com   https:  www.amazon.com
#
#                                                pathname   productId  \
# 0     /Neutrogena-Oil-Free-Eye-Makeup-Remover/dp/B00...  B000NWAOHE
# 1     /CeraVe-Facial-Moisturizing-Lotion-AM/dp/B00F9...  B00F97FHAW
# 2     /CeraVe-Hydrating-Facial-Cleanser-Fragrance/dp...  B01MSSDEPK
# 3     /Neutrogena-Cleansing-Hydrating-Oil-Free-Sensi...  B07767Z9YZ
# 4     /Dove-Body-Wash-Pump-Moisture/dp/B00MEDOY2G/re...  B00MEDOY2G
# ...                                                 ...         ...
# 1855  /American-Metalcraft-MELSQ117-Endurance-228-Ou...  B002XH17BE
# 1856  /AmazonBasics-D-Ring-Binder-White-4-Pack/dp/B0...  B077XCJ6S1
# 1857  /Fiskars-29-Inch-Machete-Axe/dp/B019EXCS2Q/ref...  B019EXCS2Q
# 1858  /Colorations-SWTALL-Simply-Washable-Tempera/dp...  B005E9K0DY
# 1859  /Fastway-80-01-2204-Zip-Breakway-Cable/dp/B007...  B00718W5GQ
#
#                                            productTitle  productGlobalReview  \
# 0     Neutrogena Oil-Free Liquid Eye Makeup Remover,...                  4.7
# 1     CeraVe AM Facial Moisturizing Lotion SPF 30 | ...                  4.5
# 2     CeraVe Hydrating Facial Cleanser | Moisturizin...                  4.7
# 3     Neutrogena Hydro Boost Gentle Cleansing and Hy...                  4.6
# 4     Dove Body Wash with Pump with Skin Natural Nou...                  4.8
# ...                                                 ...                  ...
# 1855  American Metalcraft MELSQ117 Endurance Melamin...                  4.6
# 1856  Amazon Basics Binder - 2 Inch D-Ring, White, 4...                  4.7
# 1857                        Fiskars 29 Inch Machete Axe                  4.6
# 1858  Colorations Simply Washable Tempera Paint, 19C...                  4.7
# 1859  Fastway Zip 4 Foot Breakaway Cable and Pin 80-...                  4.8
#
#      numberOfRatings  __v
# 0             19'015    0
# 1             33'334    0
# 2             51'173    0
# 3                100    0
# 4             34'808    0
# ...              ...  ...
# 1855             278    0
# 1856           4'622    0
# 1857             814    0
# 1858           4'434    0
# 1859           2'268    0
#
# [1860 rows x 15 columns]

# %%
import psycopg2
from tqdm import tqdm
import math

conn = psycopg2.connect(**{
    "host": "localhost",
    "database": "hochet",
    "user": "hochet",
    "password": "hochet"
})

def clean(s):
    return s.replace("'", "").replace('"', '')

cursor = conn.cursor()
cols = ','.join(["productid", "categories", "storeid", "storename", "href", "origin", "protocol", "host", "pathname", "producttitle", "productglobalreview", "numberofratings"])
already_inserted = []

for item in tqdm(products_df.T.to_dict().values()):
    if item['productId'] not in already_inserted:
        values = (
            item['productId'],
            item['categories'],
            item['storeId'],
            item['storeName'],
            item['href'],
            item['origin'],
            item['protocol'],
            item['host'],
            item['pathname'],
            item['productTitle'],
            item['productGlobalReview'],
            item['numberOfRatings'].replace("'", '') if item['numberOfRatings'] is not None else 0
        )

        query = "INSERT INTO public.products ({}) VALUES (%s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s)".format(cols)
        cursor.execute(query, values)
        already_inserted.append(item['productId'])

try:
    conn.commit()
except (Exception, psycopg2.DatabaseError) as error:
    conn.rollback()
    cursor.close()
cursor.close()
# Out:
# 100%|████████████████████████████████████████████████████████████████████████████| 1860/1860 [00:00<00:00, 2268.04it/s]

# %%
def compute_next_cols(row):
    stars = compute_stars([row.title, row.content, row.title + " " + row.content])
    return {
        "title_computed_stars": stars[0],
        "content_computed_stars": stars[1],
        "title_concat_content_computed_stars": stars[2],
    }

# %%
computed_stars_reviews_df = reviews_df.apply(compute_next_cols, result_type="expand", axis=1)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-8cd66e2161bf> in <module>
# ----> 1 computed_stars_reviews_df = reviews_df.apply(compute_next_cols, result_type="expand", axis=1)
#
# c:\users\guillaum.hochet\documents\master\wem\projet-amazon\jupyter\lib\site-packages\pandas\core\frame.py in apply(self, func, axis, raw, result_type, args, **kwds)
#    7766             kwds=kwds,
#    7767         )
# -> 7768         return op.get_result()
#    7769
#    7770     def applymap(self, func, na_action: Optional[str] = None) -> DataFrame:
#
# c:\users\guillaum.hochet\documents\master\wem\projet-amazon\jupyter\lib\site-packages\pandas\core\apply.py in get_result(self)
#     183             return self.apply_raw()
#     184
# --> 185         return self.apply_standard()
#     186
#     187     def apply_empty_result(self):
#
# c:\users\guillaum.hochet\documents\master\wem\projet-amazon\jupyter\lib\site-packages\pandas\core\apply.py in apply_standard(self)
#     274
#     275     def apply_standard(self):
# --> 276         results, res_index = self.apply_series_generator()
#     277
#     278         # wrap results
#
# c:\users\guillaum.hochet\documents\master\wem\projet-amazon\jupyter\lib\site-packages\pandas\core\apply.py in apply_series_generator(self)
#     288             for i, v in enumerate(series_gen):
#     289                 # ignore SettingWithCopy here in case the user mutates
# --> 290                 results[i] = self.f(v)
#     291                 if isinstance(results[i], ABCSeries):
#     292                     # If we have a view on v, we need to make a copy because
#
# <ipython-input-2-ecffb89cd6bc> in compute_next_cols(row)
#       1 def compute_next_cols(row):
# ----> 2     stars = compute_stars([row.title, row.content, row.title + " " + row.content])
#       3     return {
#       4         "title_computed_stars": stars[0],
#       5         "content_computed_stars": stars[1],
#
# NameError: name 'compute_stars' is not defined

# %%
reviews2_df = pd.concat([reviews_df, pd.DataFrame(stars_df, columns=['computed_stars'])], axis=1)
reviews2_df
# Out:
#                              _id   productId  \
# 0       60a64efdc6b6ff1874824029  B000NWAOHE
# 1       60a64efdc6b6ff187482402e  B000NWAOHE
# 2       60a64efdc6b6ff187482403e  B000NWAOHE
# 3       60a64efdc6b6ff1874824052  B000NWAOHE
# 4       60a64efdc6b6ff1874824053  B000NWAOHE
# ...                          ...         ...
# 161570  60a6b57d6dccd831e8d9906b  B00718W5GQ
# 161571  60a6b57d6dccd831e8d9906c  B00718W5GQ
# 161572  60a6b57d6dccd831e8d9906d  B00718W5GQ
# 161573  60a6b57d6dccd831e8d9906e  B00718W5GQ
# 161574  60a6b57d6dccd831e8d9906f  B00718W5GQ
# 3       Impressive product.  Right now I’m using Volum...                 0
# 4       This has been working out great for me, but I ...            4    0
# ...                                                   ...          ...  ...
# 161570  Easy to install, make sure you order one long ...         None    0
# 161571  Best one out there the cable doesn't drag or g...         None    0
# 161572                REMEMBER 4ft is completely extended         None    0
# 161573  Always a huge fan of these things. Simple easy...         None    0
# 161574  We have purchased several of these of the year...         None    0
#
#         computed_stars
# 0             3.955002
# 1             2.085644
# 2             2.028057
# 3             4.845288
# 4             3.291641
# ...                ...
# 161570        4.278356
# 161571        4.674066
# 161572        4.285427
# 161573        4.725660
# 161574        4.912704
#
# [161575 rows x 13 columns]

# %%
from datetime import datetime
import time

def format_location_date(txt):
    date = datetime.strptime(" ".join(txt.split(" ")[-3:]), "%B %d, %Y")
    location = " ".join(txt.split(" ")[2:-4])
    return pd.Series({"date": date, "location": location })

# %%
reviews2_location_date_serie = reviews2_df.apply(lambda row: format_location_date(row.fromAndDate), axis=1)
reviews2_location_date = pd.DataFrame(reviews2_location_date_serie)

# %%
reviews3_df = pd.concat([reviews2_df, reviews2_location_date], axis=1)
reviews3_df
# Out:
#                              _id   productId  \
# 0       60a64efdc6b6ff1874824029  B000NWAOHE
# 1       60a64efdc6b6ff187482402e  B000NWAOHE
# 2       60a64efdc6b6ff187482403e  B000NWAOHE
# 3       60a64efdc6b6ff1874824052  B000NWAOHE
# 4       60a64efdc6b6ff1874824053  B000NWAOHE
# ...                          ...         ...
# 161570  60a6b57d6dccd831e8d9906b  B00718W5GQ
# 161571  60a6b57d6dccd831e8d9906c  B00718W5GQ
# 161572  60a6b57d6dccd831e8d9906d  B00718W5GQ
# 161573  60a6b57d6dccd831e8d9906e  B00718W5GQ
# 161574  60a6b57d6dccd831e8d9906f  B00718W5GQ
#
#                                      storeId             author  \
# 0       3BC8CF14-3F35-41A4-9BF3-705A7FB2B6B6             Steven
# 1       3BC8CF14-3F35-41A4-9BF3-705A7FB2B6B6               Alix
# 2       3BC8CF14-3F35-41A4-9BF3-705A7FB2B6B6      Razzle Dazzle
# 3       3BC8CF14-3F35-41A4-9BF3-705A7FB2B6B6    Amazon Customer
# 4       3BC8CF14-3F35-41A4-9BF3-705A7FB2B6B6            Aundrea
# ...                                      ...                ...
# 161570  AE9F00D1-C11E-4A9B-AFEB-B4EA056EF019             joAnne
# 161571  AE9F00D1-C11E-4A9B-AFEB-B4EA056EF019              Pools
# 161572  AE9F00D1-C11E-4A9B-AFEB-B4EA056EF019  Mark Gilbertville
# 161573  AE9F00D1-C11E-4A9B-AFEB-B4EA056EF019   Jonathan Couture
# 161574  AE9F00D1-C11E-4A9B-AFEB-B4EA056EF019              Misty
#
#                                                 authorImg  \
# 0       https://images-na.ssl-images-amazon.com/images...
# 1       https://images-na.ssl-images-amazon.com/images...
# 2       https://images-na.ssl-images-amazon.com/images...
# 3       https://images-na.ssl-images-amazon.com/images...
# 4       https://images-na.ssl-images-amazon.com/images...
# ...                                                   ...
# 161570  https://images-na.ssl-images-amazon.com/images...
# 161571  https://images-na.ssl-images-amazon.com/images...
# 161572  https://images-na.ssl-images-amazon.com/images...
# 161573  https://images-na.ssl-images-amazon.com/images...
# 161574  https://images-na.ssl-images-amazon.com/images...
#
#                                                authorLink  stars  \
# 0       https://www.amazon.com/gp/profile/amzn1.accoun...    5.0
# 1       https://www.amazon.com/gp/profile/amzn1.accoun...    2.0
# 2       https://www.amazon.com/gp/profile/amzn1.accoun...    2.0
# 3       https://www.amazon.com/gp/profile/amzn1.accoun...    5.0
# 4       https://www.amazon.com/gp/profile/amzn1.accoun...    4.0
# ...                                                   ...    ...
# 161570  https://www.amazon.com/gp/profile/amzn1.accoun...    5.0
# 161571  https://www.amazon.com/gp/profile/amzn1.accoun...    5.0
# 161572  https://www.amazon.com/gp/profile/amzn1.accoun...    5.0
# 161573  https://www.amazon.com/gp/profile/amzn1.accoun...    5.0
# 161574  https://www.amazon.com/gp/profile/amzn1.accoun...    5.0
#
#                                                     title  \
# 0       Great product as long as you follow the direct...
# 1                       what does oil free actually mean?
# 2               Doesn't remove all the makeup and greasy!
# 3                                          Two thumbs up!
# 4       It's a good makeup remover, but does leave an ...
# ...                                                   ...
# 161570                                       Safety first
# 161571                                              Great
# 161572                                         Good value
# 161573                             Heavy clips and rugged
# 161574                                        love these.
#
#                                               fromAndDate  \
# 0            Reviewed in the United States on May 1, 2016
# 1       Reviewed in the United States on October 17, 2017
# 2          Reviewed in the United States on June 19, 2019
# 3       Reviewed in the United States on December 15, ...
# 4           Reviewed in the United States on June 7, 2016
# ...                                                   ...
# 161570    Reviewed in the United States on April 23, 2018
# 161571     Reviewed in the United States on July 19, 2019
# 161572     Reviewed in the United States on July 24, 2019
# 161573  Reviewed in the United States on December 17, ...
# 161574    Reviewed in the United States on March 13, 2018
#
#                                                   content foundHelpful  __v  \
# 0       I was initially so disappointed when I tried t...           15    0
# 1       I don't know if oil free means your face will ...            3    0
# 2       I was using an oil based makeup remover and it...         None    0
# 3       Impressive product.  Right now I’m using Volum...                 0
# 4       This has been working out great for me, but I ...            4    0
# ...                                                   ...          ...  ...
# 161570  Easy to install, make sure you order one long ...         None    0
# 161571  Best one out there the cable doesn't drag or g...         None    0
# 161572                REMEMBER 4ft is completely extended         None    0
# 161573  Always a huge fan of these things. Simple easy...         None    0
# 161574  We have purchased several of these of the year...         None    0
#
#         computed_stars       date           location
# 0             3.955002 2016-05-01  the United States
# 1             2.085644 2017-10-17  the United States
# 2             2.028057 2019-06-19  the United States
# 3             4.845288 2017-12-15  the United States
# 4             3.291641 2016-06-07  the United States
# ...                ...        ...                ...
# 161570        4.278356 2018-04-23  the United States
# 161571        4.674066 2019-07-19  the United States
# 161572        4.285427 2019-07-24  the United States
# 161573        4.725660 2018-12-17  the United States
# 161574        4.912704 2018-03-13  the United States
#
# [161575 rows x 15 columns]

# %%
def authorId(link):
    return pd.Series({"authorId": None if link is None else link.split('.')[-1].split('/')[0] })

reviews3_authorId = reviews3_df.apply(lambda row: authorId(row.authorLink), axis=1)
reviews3_authorId_df = pd.DataFrame(reviews3_authorId)

reviews4_df = pd.concat([reviews3_df, reviews3_authorId_df], axis=1)
reviews4_df
# Out:
#                              _id   productId  \
# 0       60a64efdc6b6ff1874824029  B000NWAOHE
# 1       60a64efdc6b6ff187482402e  B000NWAOHE
# 2       60a64efdc6b6ff187482403e  B000NWAOHE
# 3       60a64efdc6b6ff1874824052  B000NWAOHE
# 4       60a64efdc6b6ff1874824053  B000NWAOHE
# 161571     Reviewed in the United States on July 19, 2019
# 161572     Reviewed in the United States on July 24, 2019
# 161573  Reviewed in the United States on December 17, ...
# 161574    Reviewed in the United States on March 13, 2018
#
#                                                   content foundHelpful  __v  \
# 0       I was initially so disappointed when I tried t...           15    0
# 1       I don't know if oil free means your face will ...            3    0
# 2       I was using an oil based makeup remover and it...         None    0
# 3       Impressive product.  Right now I’m using Volum...                 0
# 4       This has been working out great for me, but I ...            4    0
# ...                                                   ...          ...  ...
# 161570  Easy to install, make sure you order one long ...         None    0
# 161571  Best one out there the cable doesn't drag or g...         None    0
# 161572                REMEMBER 4ft is completely extended         None    0
# 161573  Always a huge fan of these things. Simple easy...         None    0
# 161574  We have purchased several of these of the year...         None    0
#
#         computed_stars       date           location  \
# 0             3.955002 2016-05-01  the United States
# 1             2.085644 2017-10-17  the United States
# 2             2.028057 2019-06-19  the United States
# 3             4.845288 2017-12-15  the United States
# 4             3.291641 2016-06-07  the United States
# ...                ...        ...                ...
# 161570        4.278356 2018-04-23  the United States
# 161571        4.674066 2019-07-19  the United States
# 161572        4.285427 2019-07-24  the United States
# 161573        4.725660 2018-12-17  the United States
# 161574        4.912704 2018-03-13  the United States
#
#                             authorId
# 0       AGPNBTY3BSECMCV5NI52L64NDTPA
# 1       AEQEJHZVVP726OWARX2B66MSKQGQ
# 2       AEWBUQA56UXZBIP6C5YZH3237XLA
# 3       AGCEVLASYODXFXBIEIOJJSOLFTDQ
# 4       AFFCTK6Y27DONGPEBDIGH6YXH2TQ
# ...                              ...
# 161570  AG3FTTXLX6GUQ5LAPJP3QJ5D5JEA
# 161571  AE74Y7KNDXTATL7HZPLUAPSE3XFQ
# 161572  AGRFJFC5YJ44KFJSDFMFZWALH7UA
# 161573  AHNWXGCEWYP2Q44UUQ2QUQXS7MCQ
# 161574  AHGVRKRBUYULXSQ2XHMKE2F3IG3A
#
# [161575 rows x 16 columns]

# %%
import psycopg2
from tqdm import tqdm
import math
import json

conn = psycopg2.connect(**{
    "host": "localhost",
    "database": "hochet",
    "user": "hochet",
    "password": "hochet"
})

def clean(s):
    return s.replace("'", "").replace('"', '')

def execute_many(conn, df):
    cursor = conn.cursor()
    tuples = [tuple(x) for x in df.to_numpy()]
    i = 1
    
    for item in tqdm(tuples):
        productid = item[0]
        storeid = item[1]
        author = item[2].replace("'", "").replace('"', "")
        authorImg = item[3]
        authorLink = item[4]
        stars = item[5]
        title = item[6].replace("'", "").replace('"', "") if item[6] is not None else None
        content = item[8].replace("'", "").replace('"', "") if item[8] is not None else None
        computed_stars = item[10]
        date = item[11]
        location = item[12]
        authorId = item[13]
        if authorId is not None:
            query = "INSERT INTO public.updated_reviews (id, productid, storeid, author, stars, computed_stars, date, location, author_img, author_link, title, content, author_id) VALUES ({}, '{}', '{}', '{}', {}, {}, '{}', '{}', '{}', '{}', '{}', '{}', '{}')".format(i, productid, storeid, author, stars, computed_stars, date, location, authorImg, authorLink, title, content, authorId)
            cursor.execute(query)
            i = i + 1
    
    try:
        conn.commit()
    except (Exception, psycopg2.DatabaseError) as error:
        conn.rollback()
        cursor.close()
    cursor.close()
    

execute_many(conn, reviews4_df.drop(columns=['_id', '__v']))
# Out:
# 100%|████████████████████████████████████████████████████████████████████████| 161575/161575 [01:08<00:00, 2372.27it/s]
