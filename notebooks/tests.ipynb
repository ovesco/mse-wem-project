# %%
import pandas as pd
import numpy as np

all_beauty_path = '../data/All_Beauty.json'
fashion_path = '../data/AMAZON_FASHION.json'
all_beauty_meta_path = '../data/meta_All_Beauty.json'
fashion_meta_path = '../data/meta_AMAZON_FASHION.json'

# %%
all_beauty_df = pd.read_json(all_beauty_path, lines=True)
fashion_df = pd.read_json(fashion_path, lines=True)
all_beauty_meta_df = pd.read_json(all_beauty_meta_path, lines=True)
fashion_meta_df = pd.read_json(fashion_meta_path, lines=True)

# %%
all_beauty_meta_df
# Out:
#       category tech1                                        description fit  \
# 0           []        [Loud 'N Clear Personal Sound Amplifier allows...
# 1           []        [No7 Lift & Luminate Triple Action Serum 50ml ...
# 2           []        [No7 Stay Perfect Foundation now stays perfect...
# 3           []                                                       []
# 4           []        [Lacto Calamine Skin Balance Daily Nourishing ...
# ...        ...   ...                                                ...  ..
# 32887       []                                                       []
# 32888       []                                                       []
# 32889       []                                                       []
# 32890       []        [Brand new and high quality<br> Enables fast v...
# 32891       []                                                       []
#
#                                                    title  \
# ...
